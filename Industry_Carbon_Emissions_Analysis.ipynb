# %% [markdown]
# <a href="https://colab.research.google.com/github/moosakazim12/Industry-Carbon-Emissions-Analysis/blob/main/Industry_Carbon_Emissions_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SELECT industry_group,
	COUNT(DISTINCT company) AS num_companies,
    ROUND(SUM(carbon_footprint_pcf),1) AS total_industry_footprint
FROM product_emissions
	WHERE year IN (SELECT MAX(YEAR) FROM product_emissions)
GROUP BY industry_group
ORDER BY total_industry_footprint DESC;
